# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Timeline, Pie

from pyecharts.faker import Faker

# %%
x = Faker.choose()

tl = Timeline()

for i in range(2020, 2025):
    bar = (
        Bar()
        .add_xaxis(x)
        .add_yaxis('A', Faker.values())
        .add_yaxis('B', Faker.values())
        
        .set_global_opts(
            title_opts=opts.TitleOpts(title='某商家{}年营业额'.format(i))
        )
    )
    tl.add(bar, '{}年'.format(i))

tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="86ec236b7e9a4606a0eb8701cefa4a49" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_86ec236b7e9a4606a0eb8701cefa4a49 = echarts.init(
#                     document.getElementById('86ec236b7e9a4606a0eb8701cefa4a49'), 'white', {renderer: 'canvas'});
#                 var option_86ec236b7e9a4606a0eb8701cefa4a49 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "A",
#                 "legendHoverLink": true,
#                 "data": [
#                     130,
#                     144,
#                     63,
#                     95,
#                     88,
#                     26,
#                     134
#                 ],
#                 "showBackground": false,
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             {
#                 "type": "bar",
#                 "name": "B",
#                 "legendHoverLink": true,
#                 "data": [
#                     58,
#                     114,
#                     108,
#                     87,
#                     138,
#                     82,
#                     48
#                 ],
#                 "showBackground": false,
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2020\u5e74",
#                 "2021\u5e74",
#                 "2022\u5e74",
#                 "2023\u5e74",
#                 "2024\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u6cb3\u9a6c",
#                     "\u87d2\u86c7",
#                     "\u8001\u864e",
#                     "\u5927\u8c61",
#                     "\u5154\u5b50",
#                     "\u718a\u732b",
#                     "\u72ee\u5b50"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "A",
#                         "B"
#                     ],
#                     "selected": {
#                         "A": true,
#                         "B": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "bar",
#                     "name": "A",
#                     "legendHoverLink": true,
#                     "data": [
#                         115,
#                         57,
#                         25,
#                         54,
#                         100,
#                         30,
#                         38
#                     ],
#                     "showBackground": false,
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     }
#                 },
#                 {
#                     "type": "bar",
#                     "name": "B",
#                     "legendHoverLink": true,
#                     "data": [
#                         85,
#                         28,
#                         53,
#                         116,
#                         75,
#                         147,
#                         105
#                     ],
#                     "showBackground": false,
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     }
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "solid"
#                         }
#                     },
#                     "data": [
#                         "\u6cb3\u9a6c",
#                         "\u87d2\u86c7",
#                         "\u8001\u864e",

# %%
attr = Faker.choose()

tl = Timeline()

for i in range(2020, 2025):
    pie = (
        Pie()
        .add(
            '',
            [list(z) for z in zip(attr, Faker.values())],
            rosetype='radius',
            radius=['30%', '55%']
        )        
        .set_global_opts(
            title_opts=opts.TitleOpts(title='某商家{}年营业额'.format(i))
        )
    )
    tl.add(pie, '{}年'.format(i))

tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d3bb6fa15eb44d8c82085460ee8710db" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d3bb6fa15eb44d8c82085460ee8710db = echarts.init(
#                     document.getElementById('d3bb6fa15eb44d8c82085460ee8710db'), 'white', {renderer: 'canvas'});
#                 var option_d3bb6fa15eb44d8c82085460ee8710db = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "\u53ef\u4e50",
#                         "value": 72
#                     },
#                     {
#                         "name": "\u96ea\u78a7",
#                         "value": 104
#                     },
#                     {
#                         "name": "\u6a59\u6c41",
#                         "value": 51
#                     },
#                     {
#                         "name": "\u7eff\u8336",
#                         "value": 92
#                     },
#                     {
#                         "name": "\u5976\u8336",
#                         "value": 20
#                     },
#                     {
#                         "name": "\u767e\u5a01",
#                         "value": 138
#                     },
#                     {
#                         "name": "\u9752\u5c9b",
#                         "value": 45
#                     }
#                 ],
#                 "radius": [
#                     "30%",
#                     "55%"
#                 ],
#                 "center": [
#                     "50%",
#                     "50%"
#                 ],
#                 "roseType": "radius",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2020\u5e74",
#                 "2021\u5e74",
#                 "2022\u5e74",
#                 "2023\u5e74",
#                 "2024\u5e74"
#             ]
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u53ef\u4e50",
#                         "\u96ea\u78a7",
#                         "\u6a59\u6c41",
#                         "\u7eff\u8336",
#                         "\u5976\u8336",
#                         "\u767e\u5a01",
#                         "\u9752\u5c9b"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "clockwise": true,
#                     "data": [
#                         {
#                             "name": "\u53ef\u4e50",
#                             "value": 91
#                         },
#                         {
#                             "name": "\u96ea\u78a7",
#                             "value": 140
#                         },
#                         {
#                             "name": "\u6a59\u6c41",
#                             "value": 75
#                         },
#                         {
#                             "name": "\u7eff\u8336",
#                             "value": 34
#                         },
#                         {
#                             "name": "\u5976\u8336",
#                             "value": 87
#                         },
#                         {
#                             "name": "\u767e\u5a01",
#                             "value": 85
#                         },
#                         {
#                             "name": "\u9752\u5c9b",
#                             "value": 110
#                         }
#                     ],
#                     "radius": [
#                         "30%",
#                         "55%"
#                     ],
#                     "center": [
#                         "50%",
#                         "50%"
#                     ],
#                     "roseType": "radius",
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     }
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u67d0\u5546\u5bb62020\u5e74\u8425\u4e1a\u989d",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597"
#             ]
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u53ef\u4e50",
#                         "\u96ea\u78a7",
#                         "\u6a59\u6c41",
#                         "\u7eff\u8336",
#                         "\u5976\u8336",
#                         "\u767e\u5a01",
#                         "\u9752\u5c9b"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "clockwise": true,
#                     "data": [
#                         {
#                             "name": "\u53ef\u4e50",
#                             "value": 125
#                         },
#                         {
#                             "name": "\u96ea\u78a7",
#                             "value": 134
#                         },
#                         {
#                             "name": "\u6a59\u6c41",
#                             "value": 105
#                         },
#                         {
#                             "name": "\u7eff\u8336",
#                             "value": 136
#                         },
#                         {
#                             "name": "\u5976\u8336",
#                             "value": 120
#                         },
#                         {
#                             "name": "\u767e\u5a01",
#                             "value": 137
#                         },
#                         {
