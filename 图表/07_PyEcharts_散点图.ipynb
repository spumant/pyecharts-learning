# %%
import pyecharts.options as opts
from pyecharts.charts import Scatter

from pyecharts.faker import Faker

# %%
data = [
    [10.0, 8.04],
    [8.0, 6.95],
    [13.0, 7.58],
    [9.0, 8.81],
    [11.0, 8.33],
    [14.0, 9.96],
    [6.0, 7.24],
    [4.0, 4.26],
    [12.0, 10.84],
    [7.0, 4.82],
    [5.0, 5.68],
]

# %%
# 把data中第一列数据排序
data.sort(key=lambda x: x[0])

# %%
data
# Out:
# [[4.0, 4.26],
#  [5.0, 5.68],
#  [6.0, 7.24],
#  [7.0, 4.82],
#  [8.0, 6.95],
#  [9.0, 8.81],
#  [10.0, 8.04],
#  [11.0, 8.33],
#  [12.0, 10.84],
#  [13.0, 7.58],
#  [14.0, 9.96]]

# %%
x_data = [d[0] for d in data]
y_data = [d[1] for d in data]

# %%
display(x_data, y_data)
# Out:
# [4.0, 5.0, 6.0, 7.0, 8.0, 9.0, 10.0, 11.0, 12.0, 13.0, 14.0]
# [4.26, 5.68, 7.24, 4.82, 6.95, 8.81, 8.04, 8.33, 10.84, 7.58, 9.96]

# %%
c = (
    Scatter(
        init_opts=opts.InitOpts(width='800px', height='500px')
    )
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        '',
        y_axis=y_data,
        symbol_size=20,
        label_opts=opts.LabelOpts(is_show=True)
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_='value',
            splitline_opts=opts.SplitLineOpts(is_show=True)
        ),
        yaxis_opts=opts.AxisOpts(
            type_='value',
            splitline_opts=opts.SplitLineOpts(is_show=True)
        )
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ecca0ddfafaa4a499be4f32f4c1bb874" style="width:800px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ecca0ddfafaa4a499be4f32f4c1bb874 = echarts.init(
#                     document.getElementById('ecca0ddfafaa4a499be4f32f4c1bb874'), 'white', {renderer: 'canvas'});
#                 var option_ecca0ddfafaa4a499be4f32f4c1bb874 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 20,
#             "data": [
#                 [
#                     4.0,
#                     4.26
#                 ],
#                 [
#                     5.0,
#                     5.68
#                 ],
#                 [
#                     6.0,
#                     7.24
#                 ],
#                 [
#                     7.0,
#                     4.82
#                 ],
#                 [
#                     8.0,
#                     6.95
#                 ],
#                 [
#                     9.0,
#                     8.81
#                 ],
#                 [
#                     10.0,
#                     8.04
#                 ],
#                 [
#                     11.0,
#                     8.33
#                 ],
#                 [
#                     12.0,
#                     10.84
#                 ],
#                 [
#                     13.0,
#                     7.58
#                 ],
#                 [
#                     14.0,
#                     9.96
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 4.0,
#                 5.0,
#                 6.0,
#                 7.0,
#                 8.0,
#                 9.0,
#                 10.0,
#                 11.0,
#                 12.0,
#                 13.0,
#                 14.0
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ecca0ddfafaa4a499be4f32f4c1bb874.setOption(option_ecca0ddfafaa4a499be4f32f4c1bb874);
#         });
#     </script>
