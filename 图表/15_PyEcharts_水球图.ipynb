# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid

from pyecharts.globals import SymbolType

# %% [markdown]
# ### 水球图

# %%
c = (
    Liquid()
    .add('', [0.2, 0.7])
    .set_global_opts(title_opts=opts.TitleOpts(title='水球图'))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="78ade470c0624820aef1c420a21cff38" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_78ade470c0624820aef1c420a21cff38 = echarts.init(
#                     document.getElementById('78ade470c0624820aef1c420a21cff38'), 'white', {renderer: 'canvas'});
#                 var option_78ade470c0624820aef1c420a21cff38 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...

# %%
c = (
    Liquid()
    .add(
        '', 
        [0.6, 0.3],
        is_outline_show=False,  # 外边框不显示
        shape=SymbolType.RECT   # 形状
    )
    .set_global_opts(title_opts=opts.TitleOpts(title='水球图'))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="6e5a404b412c4cf3996326d9e27591dd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_6e5a404b412c4cf3996326d9e27591dd = echarts.init(
#                     document.getElementById('6e5a404b412c4cf3996326d9e27591dd'), 'white', {renderer: 'canvas'});
#                 var option_6e5a404b412c4cf3996326d9e27591dd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...
